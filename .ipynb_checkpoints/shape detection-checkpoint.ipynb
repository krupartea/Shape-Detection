# %%
import cv2 as cv

# %%
def find_shapes(img, arc_len_threshold):

    # selecting yellow-only pixels: hsv(86,30,62)
    imgHSV = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    thresholded = cv.inRange(imgHSV, (30, 20, 20), (80, 255, 255))

    contours, _ = cv.findContours(thresholded, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

    for contour in contours:
        arc_len = cv.arcLength(contour, True)
        if arc_len > 200:
                approx = cv.approxPolyDP(
                        contour, 0.02 * cv.arcLength(contour, True), True)

                # finding center of a shape (to place a label)
                M = cv.moments(approx)
                if M['m00'] != 0.0:
                        x = int(M['m10']/M['m00'])
                        y = int(M['m01']/M['m00'])

                # classifying a shape
                if len(approx) == 3:
                        label = 'Triangle'
                        color = (255, 0, 0)
                elif len(approx) == 4:
                        label = 'Rectangle'
                        color = (0, 255, 0)
                else:
                        label ='Circle'
                        color = (0, 0, 255)

                cv.drawContours(img, [approx], 0, color, 3)
                cv.putText(img, label, (x, y),
                        cv.FONT_HERSHEY_PLAIN, 2, color, 2)

    return img

# %%
VIDEO_OUTPUT_PATH = r'D:\Desktop\shape detection\Shape-Detection\output.mp4'
fourcc = cv.VideoWriter_fourcc(*'mp4v')
framerate = 30
size = (1920, 1080)

output = cv.VideoWriter(VIDEO_OUTPUT_PATH, fourcc, framerate, size)

VIDEO_INPUT_PATH = r'D:\Desktop\shape detection\Shape-Detection\Test task1_video.mp4'
cap = cv.VideoCapture(VIDEO_INPUT_PATH)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    processed = find_shapes(frame, 200)
    output.write(processed)

cap.release()
output.release()
# Out:
# Can't receive frame (stream end?). Exiting ...
